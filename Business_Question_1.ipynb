# %% [markdown]
# <a href="https://colab.research.google.com/github/acshon99/consumer-behavior/blob/main/Business_Question_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 1: Consumer Characteristics by Shopping Preference
#
# What are the key characterisitics (demographic, digital habits, spending) that differentiate consumers based on their primary *shopping_preference* (online, in-store, hybrid)?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sohaibdevv/consumer-shopping-behavior-and-preference-study-2026")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'consumer-shopping-behavior-and-preference-study-2026' dataset.
# Path to dataset files: /kaggle/input/consumer-shopping-behavior-and-preference-study-2026

# %%
# Creating the 'shopping_preference_category'.
df['shopping_preference_category'] = df['shopping_preference']
print("Value counts for the new shopping_preference_category column:")
print(df['shopping_preference_category'].value_counts())

# Grouping by shopping_preference_category and calculating the mean for numerical features
features_to_compare = df.select_dtypes(include=[np.number]).columns.tolist()

preference_characteristics = df.groupby('shopping_preference_category')[features_to_compare].mean()
print(preference_characteristics)

display(preference_characteristics.style.background_gradient(cmap='Blues'))
# Out:
# Value counts for the new shopping_preference_category column:
# shopping_preference_category
# Store     10244
# Online     1176
# Hybrid      369
# Name: count, dtype: int64
#                                     age  monthly_income  daily_internet_hours  \
# shopping_preference_category
# Hybrid                        47.872629   133405.186992              6.183469
# Online                        49.789116   130299.231293              6.337840
# Store                         48.638618   131804.312280              5.967688
#
#                               smartphone_usage_years  social_media_hours  \
# shopping_preference_category
# Hybrid                                      7.590786            2.509756
# Online                                      7.551020            2.493707
# Store                                       7.603573            2.517025
#
#                               online_payment_trust_score  tech_savvy_score  \
# shopping_preference_category
# ...

# %% [markdown]
# # Explanation:
#
# To address this question, I needed to re-create a single *shopping_preference_category* column from the one-hot encoded columns (*shopping_preference_online*, *shopping_preference_store*).
#
# Based on the arguement used during the one-hot encoding, the categories are defined as follows:
# - If *shopping_preference_online* is *True*, the preference is **Online**.
# - If *shopping_preference_store* is *True*, the preference is **Store**.
# - If both *shopping_preference_online* and *shopping_preference_store* are *False*, the preference is **Hybrid**.
#
# After creating the columns, I regrouped the dataframe by *shopping_preference_category* and calculate the mean of various numerical features to compare the characteristics of each consumer segment.
#
# Demographic factors like *age* and *monthly_income* shows minor variations across these groups, suggesting that shopping preferences is more strongly driven by digital habits, and specific behavioral traits rather than broad demographics.
