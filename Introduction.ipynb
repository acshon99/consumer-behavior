# %% [markdown]
# <a href="https://colab.research.google.com/github/acshon99/consumer-behavior/blob/main/Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Consumers Behavior (2026) Dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sohaibdevv/consumer-shopping-behavior-and-preference-study-2026")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'consumer-shopping-behavior-and-preference-study-2026' dataset.
# Path to dataset files: /kaggle/input/consumer-shopping-behavior-and-preference-study-2026

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_list = os.listdir(path)
print("Dataset:", file_list)

# Print first 5 rows of dataset
df = pd.read_csv(path + "/" + file_list[0])
df.head()
# Out:
# Dataset: ['Consumer_Shopping_Trends_2026 (6).csv']
#    age  monthly_income  daily_internet_hours  smartphone_usage_years  \
# 0   56          221111                   6.5                      12
# 1   69           96029                   8.2                      13
# 2   46           19055                   6.4                       4
# 3   32           53170                   6.4                      11
# 4   60          244016                   6.0                       5
#
#    social_media_hours  online_payment_trust_score  tech_savvy_score  \
# 0                 0.7                           1                 6
# 1                 2.7                           6                 9
# 2                 2.1                          10                 8
# 3                 0.7                           2                10
# 4                 0.7                           2                 5
#
#    monthly_online_orders  monthly_store_visits  avg_online_spend  ...  \
# ...

# %%
# Print information of Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11789 entries, 0 to 11788
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          11789 non-null  int64
#  1   monthly_income               11789 non-null  int64
#  2   daily_internet_hours         11789 non-null  float64
#  3   smartphone_usage_years       11789 non-null  int64
#  4   social_media_hours           11789 non-null  float64
#  5   online_payment_trust_score   11789 non-null  int64
#  6   tech_savvy_score             11789 non-null  int64
#  7   monthly_online_orders        11789 non-null  int64
#  8   monthly_store_visits         11789 non-null  int64
#  9   avg_online_spend             11789 non-null  int64
#  10  avg_store_spend              11789 non-null  int64
#  11  discount_sensitivity         11789 non-null  int64
#  12  return_frequency             11789 non-null  int64
# ...

# %%
# First step to exploration

file_list = os.listdir(path)
csv_files = [file for file in file_list if file.endswith('.csv')]
df = pd.read_csv(os.path.join(path, csv_files[0]))

fig, axs = plt.subplots(2, 3, figsize=(15, 10))
axes = axs.flatten()

num_features = ['age', 'monthly_income', 'avg_online_spend', 'avg_store_spend', 'daily_internet_hours', 'social_media_hours']

for i, feature in enumerate(num_features):
    sns.histplot(df[feature], kde=True, ax=axes[i])
    axes[i].set_title(f'Distribution of {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Frequency')

plt.tight_layout()

# %%
# Display the descriptive statistics for numerical columns
display(df.describe())
# Out:
#                 age  monthly_income  daily_internet_hours  \
# count  11789.000000    11789.000000          11789.000000
# mean      48.729409   131704.282382              6.011367
# std       17.899445    68120.726684              1.976811
# min       18.000000    15005.000000              1.000000
# 25%       33.000000    72450.000000              4.600000
# 50%       49.000000   131916.000000              6.000000
# 75%       64.000000   190505.000000              7.400000
# max       79.000000   249989.000000             12.000000
#
#        smartphone_usage_years  social_media_hours  online_payment_trust_score  \
# count            11789.000000        11789.000000                11789.000000
# mean                 7.597930            2.514471                    5.498770
# std                  4.011628            1.263047                    2.880366
# min                  1.000000            0.000000                    1.000000
# ...

# %%
behavioral_scores = ['tech_savvy_score', 'brand_loyalty_score', 'impulse_buying_score', 'environmental_awareness']

# Group by Gender and calculate the mean of the specified behavioral scores
gender_behavior_analysis = df.groupby('gender')[behavioral_scores].mean()

print("Analysis of Behavioral Scores by Gender:")
print(gender_behavior_analysis)
# Out:
# Analysis of Behavioral Scores by Gender:
#         tech_savvy_score  brand_loyalty_score  impulse_buying_score  \
# gender
# Female          5.591198             5.492750              5.531926
# Male            5.469239             5.527988              5.453354
# Other           5.543165             5.575797              5.474049
#
#         environmental_awareness
# gender
# Female                 5.444671
# Male                   5.425113
# Other                  5.476362

# %% [markdown]
# # Explanation:
#  The analysis of behavioral scores by gender revelas:
#  - **tech_savvy_score**: Females have a slightly higher average tech-savvy score compared to Males and Others.
#  - **brand_loyalty_score**: All gender categories show similar averag brand loyalty scores that indicate little differences.
#  - **impulse_buying_score**: Females exhibit a slightly higher average impulse buying score.
#  - **environmental_awareness**: Females show a marginally higher average environmental awareness score.
#
#  Overall, there are minor differences that exist, but the behavioral scores are quite similar across the gender categories, which might suggest that gender is not a primary driver of these specific behavioral traits in the dataset.

# %%
city_tier_analysis = df.groupby('city_tier')[['tech_savvy_score', 'brand_loyalty_score', 'impulse_buying_score', 'environmental_awareness']].mean()

print("Analysis of Behavioral Scores by City Tier:")
print(city_tier_analysis)
# Out:
# Analysis of Behavioral Scores by City Tier:
#            tech_savvy_score  brand_loyalty_score  impulse_buying_score  \
# city_tier
# Tier 1             5.483677             5.462330              5.414867
# Tier 2             5.587610             5.582945              5.581130
# Tier 3             5.533300             5.552545              5.465941
#
#            environmental_awareness
# city_tier
# Tier 1                    5.459317
# Tier 2                    5.463712
# Tier 3                    5.422892

# %% [markdown]
# The table displays the average behavioral scores (*tech_savvy_score*, *brand_loyalty_score*, *impulse_buying_score*, *environmental_awareness*) across different city tiers:
# - **Minimal Variation**: For all behavioral scores, the average values are close across Tiers 1, 2, and 3 cities,
# - **No Distinct Trends**: There aren't any trends or significant differences that indicate that residents of one city tier are notably more or less *tech_savvy*, *brand_loyalty*, *impulsive*, or *environmentally_aware* than those in other tiers.
#
# It may suggest that *city_tier* doesnt have significant influence on these particular behavioral scores, that could imply that these traits are moreuniversal or influenced by factors other than urban classification.

# %%
# Out:
# Average Behavioral Scores by Age Group:
#           tech_savvy_score           brand_loyalty_score            \
#                        var      mean                 var      mean
# age_group
# 18-29             8.109031  5.562216            8.167857  5.478202
# 30-44             8.180732  5.535579            8.194860  5.591956
# 45-59             8.630700  5.473964            8.171072  5.582005
# 60+               8.370295  5.561608            7.982965  5.480934
#
#           impulse_buying_score           environmental_awareness
#                            var      mean                     var      mean
# age_group
# 18-29                 8.092905  5.497275                8.175146  5.478656
# 30-44                 8.372475  5.505672                8.237991  5.375387
# 45-59                 8.380523  5.473964                8.237668  5.519306
# 60+                   8.256690  5.474708                8.316902  5.434760

# %%
# Group by age group and calculate the mean for behavioral scores
age_behavior_variation = df.groupby('age_group', observed=False)[behavioral_scores].mean().reset_index()

print("Average behavioral scores by Age Group:")
display(age_behavior_variation)

# Visualize the variation by age group
fig, axes = plt.subplots(2, 2, figsize=(16, 12), sharex=True)
axes = axes.flatten()

for i, score in enumerate(behavioral_scores):
    sns.barplot(x='age_group', y=score, data=age_behavior_variation, ax=axes[i], palette='viridis')
    axes[i].set_title(f'Average {score.replace("_", " ").title()} by Age Group')
    axes[i].set_xlabel('Age Group')
    axes[i].set_ylabel(score.replace("_", " ").title())
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
# Out:
# Average behavioral scores by Age Group:
#   age_group  tech_savvy_score  brand_loyalty_score  impulse_buying_score  \
# 0     18-24          5.636364             5.487956              5.622378
# 1     25-34          5.469366             5.456047              5.446990
# 2     35-44          5.562917             5.663071              5.475603
# 3     45-54          5.464097             5.558078              5.486800
# 4     55-64          5.507479             5.556624              5.428953
# 5       65+          5.574863             5.480082              5.495536
#
#    environmental_awareness
# 0                 5.551671
# 1                 5.344699
# 2                 5.405239
# 3                 5.512144
# 4                 5.499466
# 5                 5.424794
# /tmp/ipykernel_11234/1388848595.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# ...

# %% [markdown]
# # Explanation:
#
# The table illustrates various behavioral scores that change across different age groups:
# - **tech_savvy_score**: Peaks in the younger age groups (18-24, 25-34) and steadily declines with increasing age. It aligns with general expectations of digital native generations.
# - **brand_loyalty_score**: Shows a more complex pattern, generally increasing from youger groups, peaking in middle-aged groups (35-44, 45-54), and then slightly decreasing in older groups. This suggests that brand loyalty may develop and solidify over time.
# - **impulse_buying_score**: Tends to be higher in younger age groups (18-24, 25-34) and gradually decreases as consumers get older. Younger consumers might be more prone to spontaneous purchases.
# - **environmental_awareness**: Similar to tech-saviness and impulse buying, environmental awareness scores are generally higher in younger age groups and show a slight decline with increasing age
#
# *age_group* appears to be a notable factor that influences behavioral scores, with the younger demographic often scoring higher in tech-saviness, impulsivity, and environmental awareness, while brand loyalty tends to be the strongest in middle-aged consumers,

# %%
# Exclude the target itself, and reconstructed categorical columns from features
features_for_regression = [col for col in df.columns if col not in ['avg_online_spend', 'shopping_preference_category', 'city_tier_category', 'age_group', 'income_group', 'gender_category', 'cluster_3', 'cluster_4']]

X = df[features_for_regression]
y = df['avg_online_spend']

print(f"Features for regression: {X.shape[1]} columns")
print(f"Target variable: {y.name}")
display(X.head())
# Out:
# Features for regression: 24 columns
# Target variable: avg_online_spend
#    age  monthly_income  daily_internet_hours  smartphone_usage_years  \
# 0   56          221111                   6.5                      12
# 1   69           96029                   8.2                      13
# 2   46           19055                   6.4                       4
# 3   32           53170                   6.4                      11
# 4   60          244016                   6.0                       5
#
#    social_media_hours  online_payment_trust_score  tech_savvy_score  \
# 0                 0.7                           1                 6
# 1                 2.7                           6                 9
# 2                 2.1                          10                 8
# 3                 0.7                           2                10
# 4                 0.7                           2                 5
#
# ...
